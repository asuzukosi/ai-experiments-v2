# %% [markdown]
# ## Zero-shot classification with embeddings
#
# In this notebook we will classify the sentiment of reviews using embeddings and zero labeled data! The dataset is created in the [Get_embeddings_from_dataset Notebook](Get_embeddings_from_dataset.ipynb).
#
# We'll define positive sentiment to be 4- and 5-star reviews, and negative sentiment to be 1- and 2-star reviews. 3-star reviews are considered neutral and we won't use them for this example.
#
# We will perform zero-shot classification by embedding descriptions of each class and then comparing new samples to those class embeddings.

# %%
import pandas as pd
import numpy as np
from ast import literal_eval

from sklearn.metrics import classification_report

EMBEDDING_MODEL = "text-embedding-3-small"

# %%
datafile_path = input("Enter the path to the data file: ")

# %%
df = pd.read_csv(datafile_path)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ProductId', 'UserId', 'Score', 'Summary', 'Text',
#        'combined', 'n_tokens', 'embedding'],
#       dtype='object')

# %%
df["UserId"].head()
# Out:
# 0    A3R7JR3FMEBXQB
# 1    A21VWSCGW7UUAR
# 2    A34XBAIFT02B60
# 3    A14MQ40CCU8B13
# 4    A34XBAIFT02B60
# Name: UserId, dtype: object

# %%
df["combined"].head()
# Out:
# 0    Title: where does one  start...and stop... wit...
# 1    Title: Good, but not Wolfgang Puck good; Conte...
# 2    Title: Should advertise coconut as an ingredie...
# 3    Title: Best tomato soup; Content: I have a har...
# 4    Title: Should advertise coconut as an ingredie...
# Name: combined, dtype: object

# %%
type(df["embedding"][0])
# Out:
# str

# %%
df["embedding"][0]
# Out:
# '[0.03599238395690918, -0.02116263099014759, -0.02902303636074066, 0.009706169366836548, -0.015163900330662727, -0.05273154750466347, -0.01680281013250351, 0.05333619564771652, -0.024154040962457657, -0.01953963190317154, 0.047894373536109924, -0.013302224688231945, 0.016675516963005066, 0.005688451696187258, 0.019014544785022736, 0.0009184064692817628, 0.018982721492648125, 0.019316866993904114, 0.04032038152217865, 0.08127722889184952, 0.05413178354501724, 0.005449775140732527, -0.00773311173543334, 0.007347251754254103, 0.031521182507276535, -0.011695138178765774, -0.02467912808060646, 0.015609429217875004, 0.04152967408299446, -0.040161263197660446, -0.04499843716621399, -0.0358969122171402, -0.014797929674386978, -0.0335419736802578, 0.019873779267072678, 0.037424441426992416, 0.015919707715511322, -0.007327361963689327, 0.0072239357978105545, 0.0019113993039354682, 0.005151429679244757, 0.036533381789922714, 0.04538031667470932, 0.02822744846343994, 0.025617921724915504, 0.017009662464261055, 0.0047973934561014175, 0.004916731268167496, -0.02148086577653885, 0.00030356639763340354, 0.03831550106406212, 0.04305720329284668, -0.02902303636074066, -0.03225312381982803, 0.013079460710287094, 0.003361357608810067, -0.029659505933523178, -0.007371119223535061, 0.012188402004539967, -0.008142839185893536, 0.025347420945763588, -0.0250132754445076, 0.06485630571842194, 0.0007642613491043448, 0.028004683554172516, -0.06103748083114624, -0.012618019245564938, -0.020876219496130943, -0.028434300795197487, 0.008142839185893536, -0.02078074775636196, 0.01562534086406231, -0.031505268067121506, -0.017900722101330757, 0.00015638269542250782, -0.0005708340904675424, -0.03048691712319851, 0.0012073041871190071, -0.023549392819404602, -0.05079031363129616, -0.02658853866159916, 0.013381783850491047, -0.02121036686003208, -0.028307007625699043, 0.012912387028336525, -0.05645489692687988, -0.010915461927652359, 0.01756657473742962, 0.005119606386870146, -0.005915193818509579, 0.0063249217346310616, -0.015665119513869286, -0.020542072132229805, 0.026429420337080956, 0.015251414850354195, -0.014583121053874493, -0.0211148951202631, 0.053368017077445984, 0.010668830014765263, -0.02547471597790718, 0.03634244203567505, -0.029675418511033058, -0.01580832526087761, 0.013930738903582096, 0.05126766487956047, -0.017741603776812553, 0.03360562026500702, 0.04786255210638046, -0.024535922333598137, -0.008146816864609718, -0.03177576884627342, -0.04152967408299446, -0.002027753973379731, 0.011193918064236641, -0.010613138787448406, 0.0765037089586258, -0.04184791073203087, -0.08458687365055084, 0.012816916219890118, 0.03405115008354187, -0.026890860870480537, 0.008290022611618042, -0.017073310911655426, -0.03904743865132332, -0.02852977253496647, -0.024933716282248497, 0.04175243899226189, 0.0003314119821880013, 0.04334361478686333, -0.013962563127279282, 0.049899253994226456, -0.01879177987575531, 0.011894035153090954, -0.025140568614006042, -0.01912592723965645, 0.02078074775636196, -0.035387735813856125, -0.029293537139892578, -0.04697149246931076, 0.03799726441502571, -0.0026154944207519293, -0.061292070895433426, 0.008910581469535828, -0.0030988138169050217, 0.05034478381276131, -0.02977088838815689, -0.046748727560043335, 0.04079773277044296, 0.013700018636882305, -0.0026771523989737034, 0.00644823769107461, 0.013238578103482723, -0.04970831423997879, 0.02270607091486454, 0.0211944542825222, -0.06345606595277786, 0.001193381380289793, 0.02743186056613922, -0.032682739198207855, 0.03834732249379158, 0.012801004573702812, -0.010446065105497837, -0.03433756157755852, -0.013143107295036316, -0.044043730944395065, -0.0008134883246384561, 0.00703697232529521, 0.01957145519554615, -0.04703513905405998, -0.06644748151302338, -0.020430689677596092, -0.03430573642253876, 0.01075634453445673, -0.008878758177161217, -0.033701092004776, -0.03056647628545761, 0.005815745331346989, -0.008910581469535828, -0.03631062060594559, -0.021783189848065376, 0.0208603069 ...

# %%
df["embedding"] = df.embedding.apply(literal_eval).apply(np.array)

# %%
type(df["embedding"][0])
# Out:
# numpy.ndarray

# %%
df["embedding"][0].shape
# Out:
# (1536,)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ProductId', 'UserId', 'Score', 'Summary', 'Text',
#        'combined', 'n_tokens', 'embedding'],
#       dtype='object')

# %%
df["embedding"].shape
# Out:
# (1000,)

# %%
df["Score"].head()
# Out:
# 0    5
# 1    4
# 2    1
# 3    5
# 4    1
# Name: Score, dtype: int64

# %%
# convert 5-star rating to binary sentiment
df = df[df.Score != 3]
df["sentiment"] = df.Score.replace({1: "negative", 2: "negative", 4: "positive", 5: "positive"})

# %%
df["sentiment"].head()
# Out:
# 0    positive
# 1    positive
# 2    negative
# 3    positive
# 4    negative
# Name: sentiment, dtype: object

# %% [markdown]
# ### Zero-Shot Classification
# To perform zero shot classification, we want to predict labels for our samples without any training. To do this, we can simply embed short descriptions of each label, such as positive and negative, and then compare the cosine distance between embeddings of samples and label descriptions.
#
# The highest similarity label to the sample input is the predicted label. We can also define a prediction score to be the difference between the cosine distance to the positive and to the negative label. This score can be used for plotting a precision-recall curve, which can be used to select a different tradeoff between precision and recall, by selecting a different threshold.

# %%
from openai import OpenAI
from typing import List
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_embedding(text: str, model: str = "text-embedding-3-small", *args, **kwargs) -> list[float]:
    text = text.replace("\n", " ")
    result = client.embeddings.create(
        model=model,
        input=text,
        *args,
        **kwargs
    )
    return result.data[0].embedding

async def aget_embedding(text: str, model: str = "text-embedding-3-small", *args, **kwargs) -> list[float]:
    text = text.replace("\n", " ")
    result = await client.embeddings.create(
        model=model,
        input=text,
        *args,
        **kwargs
    )

def get_embeddings(texts: List[str], model: str = "text-embedding-3-small",
 *args, **kwargs) -> list[list[float]]:
    assert len(texts) > 0, "texts must be a non-empty list"
    assert len(texts) < 2048, "text list must be less than 2048 texts"

    result = client.embeddings.create(
        model=model,
        input=texts,
        *args,
        **kwargs
    )
    return [d.embedding for d in result.data]

async def aget_embeddings(texts: List[str], 
    model: str = "text-embedding-3-small", 
    *args, **kwargs) -> list[list[float]]:
    assert len(texts) > 0, "texts must be a non-empty list"
    assert len(texts) < 2048, "text list must be less than 2048 texts"

    result = await client.embeddings.create(
        model=model,
        input=texts,
        *args,
        **kwargs
    )
    return [d.embedding for d in result.data]

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
from sklearn.metrics import PrecisionRecallDisplay

def evaluate_embeddings_approach(
    labels = ['negative', 'positive'],
    model = EMBEDDING_MODEL,
):
    label_embeddings = [get_embedding(label, model=model) for label in labels]

    def label_score(review_embedding, label_embeddings):
        return cosine_similarity(review_embedding, label_embeddings[1]) - cosine_similarity(review_embedding, label_embeddings[0])

    probas = df["embedding"].apply(lambda x: label_score(x, label_embeddings))
    preds = probas.apply(lambda x: 'positive' if x>0 else 'negative')

    report = classification_report(df.sentiment, preds)
    print(report)

    display = PrecisionRecallDisplay.from_predictions(df.sentiment, probas, pos_label='positive')
    _ = display.ax_.set_title("2-class Precision-Recall curve")

evaluate_embeddings_approach(labels=['negative', 'positive'], model=EMBEDDING_MODEL)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 21
#      18     display = PrecisionRecallDisplay.from_predictions(df.sentiment, probas, pos_label='positive')
#      19     _ = display.ax_.set_title("2-class Precision-Recall curve")
# ---> 21 evaluate_embeddings_approach(labels=['negative', 'positive'], model=EMBEDDING_MODEL)
#
# Cell In[9], line 7, in evaluate_embeddings_approach(labels, model)
#       3 def evaluate_embeddings_approach(
#       4     labels = ['negative', 'positive'],
#       5     model = EMBEDDING_MODEL,
#       6 ):
# ----> 7     label_embeddings = [get_embedding(label, model=model) for label in labels]
#       9     def label_score(review_embedding, label_embeddings):
#      10         return cosine_similarity(review_embedding, label_embeddings[1]) - cosine_similarity(review_embedding, label_embeddings[0])
#
# Cell In[8], line 9, in get_embedding(text, model, *args, **kwargs)
#       7 def get_embedding(text: str, model: str = "text-embedding-3-small", *args, **kwargs) -> list[float]:
#       8     text = text.replace("\n", " ")
# ----> 9     result = client.embeddings.create(
#      10         model=model,
#      11         input=text,
#      12         *args,
#      13         **kwargs
#      14     )
#      15     return result.data[0].embedding
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:1039, in cached_property.__get__(self, instance, owner)
#    1037 val = cache.get(self.attrname, _NOT_FOUND)
#    1038 if val is _NOT_FOUND:
# -> 1039     val = self.func(instance)
#    1040     try:
#    1041         cache[self.attrname] = val
#
# File ~/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/_client.py:193, in embeddings(self)
#     175 @property
#     176 @override
#     177 def default_headers(self) -> dict[str, str | Omit]:
#     178     return {
#     179         **super().default_headers,
#     180         "X-Stainless-Async": "false",
#    (...)    183         **self._custom_headers,
#     184     }
#     186 def copy(
#     187     self,
#     188     *,
#     189     api_key: str | None = None,
#     190     organization: str | None = None,
#     191     project: str | None = None,
#     192     websocket_base_url: str | httpx.URL | None = None,
# --> 193     base_url: str | httpx.URL | None = None,
#     194     timeout: float | Timeout | None | NotGiven = NOT_GIVEN,
#     195     http_client: httpx.Client | None = None,
#     196     max_retries: int | NotGiven = NOT_GIVEN,
#     197     default_headers: Mapping[str, str] | None = None,
#     198     set_default_headers: Mapping[str, str] | None = None,
#     199     default_query: Mapping[str, object] | None = None,
#     200     set_default_query: Mapping[str, object] | None = None,
#     201     _extra_kwargs: Mapping[str, Any] = {},
#     202 ) -> Self:
#     203     """
#     204     Create a new client instance re-using the same options given to the current client with optional overriding.
#     205     """
#     206     if default_headers is not None and set_default_headers is not None:
#
# File ~/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/resources/__init__.py:67
#      51 from .batches import (
#      52     Batches,
#      53     AsyncBatches,
#    (...)     57     AsyncBatchesWithStreamingResponse,
#      58 )
#      59 from .uploads import (
#      60     Uploads,
#      61     AsyncUploads,
#    (...)     65     AsyncUploadsWithStreamingResponse,
#      66 )
# ---> 67 from .responses import (
#      68     Responses,
#      69     AsyncResponses,
#      70     ResponsesWithRawResponse,
#      71     AsyncResponsesWithRawResponse,
#      72     ResponsesWithStreamingResponse,
#      73     AsyncResponsesWithStreamingResponse,
#      74 )
#      75 from .embeddings import (
#      76     Embeddings,
#      77     AsyncEmbeddings,
#    (...)     81     AsyncEmbeddingsWithStreamingResponse,
#      82 )
#      83 from .completions import (
#      84     Completions,
#      85     AsyncCompletions,
#    (...)     89     AsyncCompletionsWithStreamingResponse,
#      90 )
#
# File ~/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/resources/responses/__init__.py:3
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
# ----> 3 from .responses import (
#       4     Responses,
#       5     AsyncResponses,
#       6     ResponsesWithRawResponse,
#       7     AsyncResponsesWithRawResponse,
#       8     ResponsesWithStreamingResponse,
#       9     AsyncResponsesWithStreamingResponse,
#      10 )
#      11 from .input_items import (
#      12     InputItems,
#      13     AsyncInputItems,
#    (...)     17     AsyncInputItemsWithStreamingResponse,
#      18 )
#      20 __all__ = [
#      21     "InputItems",
#      22     "AsyncInputItems",
#    (...)     32     "AsyncResponsesWithStreamingResponse",
#      33 ]
#
# File ~/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/resources/responses/responses.py:22
#      20 from ..._resource import SyncAPIResource, AsyncAPIResource
#      21 from ..._response import to_streamed_response_wrapper, async_to_streamed_response_wrapper
# ---> 22 from .input_items import (
#      23     InputItems,
#      24     AsyncInputItems,
#      25     InputItemsWithRawResponse,
#      26     AsyncInputItemsWithRawResponse,
#      27     InputItemsWithStreamingResponse,
#      28     AsyncInputItemsWithStreamingResponse,
#      29 )
#      30 from ..._streaming import Stream, AsyncStream
#      31 from ...lib._tools import PydanticFunctionTool, ResponsesPydanticFunctionTool
#
# File ~/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/resources/responses/input_items.py:19
#      17 from ..._base_client import AsyncPaginator, make_request_options
#      18 from ...types.responses import input_item_list_params
# ---> 19 from ...types.responses.response_item_list import Data
#      21 __all__ = ["InputItems", "AsyncInputItems"]
#      24 class InputItems(SyncAPIResource):
#
# ImportError: cannot import name 'Data' from 'openai.types.responses.response_item_list' (/Users/kosisochukwuasuzu/Developer/ai-experiments-v2/venv/lib/python3.13/site-packages/openai/types/responses/response_item_list.py)

# %% [markdown]
# We can see that this classifier already performs extremely well. We used similarity embeddings, and the simplest possible label name. Let's try to improve on this by using more descriptive label names, and search embeddings.

# %%
evaluate_embeddings_approach(labels=['An Amazon review with a negative sentiment.', 'An Amazon review with a positive sentiment.'])
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.96      0.85       136
#     positive       0.99      0.95      0.97       789
#
#     accuracy                           0.95       925
#    macro avg       0.88      0.96      0.91       925
# weighted avg       0.96      0.95      0.95       925

# %% [markdown]
# Using the search embeddings and descriptive names leads to an additional improvement in performance.

# %%
evaluate_embeddings_approach(labels=['An Amazon review with a negative sentiment.', 'An Amazon review with a positive sentiment.'])
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.96      0.85       136
#     positive       0.99      0.95      0.97       789
#
#     accuracy                           0.95       925
#    macro avg       0.88      0.96      0.91       925
# weighted avg       0.96      0.95      0.95       925

# %% [markdown]
# As shown above, zero-shot classification with embeddings can lead to great results, especially when the labels are more descriptive than just simple words.
