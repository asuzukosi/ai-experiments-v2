# %% [markdown]
# # A3C Implementation
#
# This notebook demonstrates the A3C architecture implementation.

# %%
import torch
import torch.nn as nn
from models.a3c import A3C
from config.config import A3CConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement A3C model demonstration
config = A3CConfig()
model = A3C(config)
print(model)
