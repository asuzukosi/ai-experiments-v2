# %% [markdown]
# # PPO Implementation
#
# This notebook demonstrates the PPO architecture implementation.

# %%
import torch
import torch.nn as nn
from models.ppo import PPO
from config.config import PPOConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement PPO model demonstration
config = PPOConfig()
model = PPO(config)
print(model)
