# %% [markdown]
# # Dreamer Implementation
#
# This notebook demonstrates the Dreamer architecture implementation.

# %%
import torch
import torch.nn as nn
from models.dreamer import Dreamer
from config.config import DreamerConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement Dreamer model demonstration
config = DreamerConfig()
model = Dreamer(config)
print(model)
