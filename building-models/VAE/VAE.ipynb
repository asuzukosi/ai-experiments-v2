# %% [markdown]
# # VAE Implementation
#
# This notebook demonstrates the VAE architecture implementation.

# %%
import torch
import torch.nn as nn
from models.vae import VAE
from config.config import VAEConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement VAE model demonstration
config = VAEConfig()
model = VAE(config)
print(model)
