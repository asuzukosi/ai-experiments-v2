# %% [markdown]
# # GAN Implementation
#
# This notebook demonstrates the GAN architecture implementation.

# %%
import torch
import torch.nn as nn
from models.gan import GAN
from config.config import GANConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement GAN model demonstration
config = GANConfig()
model = GAN(config)
print(model)
