# %%
import torch
import torch.distributed as dist
import torch.multiprocessing as mp
import os
import subprocess
import sys
from typing import List, Dict, Any

# %%
torch.cuda.device_count()
# Out:
# 2

# %%
torch.version.cuda
# Out:
# '12.1'

# %%
for i in range(torch.cuda.device_count()):
    gpu_name = torch.cuda.get_device_name(i)
    print(f"GPU {i}: {gpu_name}")
    capacity = torch.cuda.get_device_capability(i)
    print(f"GPU {i} capability: {capacity}")
    print(f"GPU {i} memory: {torch.cuda.get_device_properties(i).total_memory / 1024 ** 3:.2f} GB")
# Out:
# GPU 0: NVIDIA GeForce RTX 4060 Ti
# GPU 0 capability: (8, 9)
# GPU 0 memory: 15.60 GB
# GPU 1: NVIDIA GeForce RTX 4060 Ti
# GPU 1 capability: (8, 9)
# GPU 1 memory: 15.60 GB

# %%
import torch.distributed

torch.distributed.is_available()
# Out:
# True

# %%
torch.distributed.is_nccl_available()
# Out:
# True

# %%
torch.distributed.is_gloo_available()
# Out:
# True

# %%
torch.distributed.get_rank()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 torch.distributed.get_rank()
#
# File ~/miniconda3/envs/lgm-py310/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:1532, in get_rank(group)
#    1529 if _rank_not_in_group(group):
#    1530     return -1
# -> 1532 default_pg = _get_default_group()
#    1533 if group is None or group is GroupMember.WORLD:
#    1534     return default_pg.rank()
#
# File ~/miniconda3/envs/lgm-py310/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:977, in _get_default_group()
#     975 """Get the default process group created by init_process_group."""
#     976 if not is_initialized():
# --> 977     raise ValueError(
#     978         "Default process group has not been initialized, "
#     979         "please make sure to call init_process_group."
#     980     )
#     981 return GroupMember.WORLD
#
# ValueError: Default process group has not been initialized, please make sure to call init_process_group.
