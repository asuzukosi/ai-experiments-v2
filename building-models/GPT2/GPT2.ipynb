# %% [markdown]
# # GPT2 Implementation
#
# This notebook demonstrates the GPT2 architecture implementation.

# %%
import torch
import torch.nn as nn
from models.gpt2 import GPT2
from config.config import GPT2Config

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement GPT2 model demonstration
config = GPT2Config()
model = GPT2(config)
print(model)
