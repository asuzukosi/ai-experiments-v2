# %% [markdown]
# # GCN Implementation
#
# This notebook demonstrates the GCN architecture implementation.

# %%
import torch
import torch.nn as nn
from models.gcn import GCN
from config.config import GCNConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement GCN model demonstration
config = GCNConfig()
model = GCN(config)
print(model)
