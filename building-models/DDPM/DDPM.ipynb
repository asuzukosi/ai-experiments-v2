# %% [markdown]
# # DDPM Implementation
#
# This notebook demonstrates the DDPM architecture implementation.

# %%
import torch
import torch.nn as nn
from models.ddpm import DDPM
from config.config import DDPMConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement DDPM model demonstration
config = DDPMConfig()
model = DDPM(config)
print(model)
