# %% [markdown]
# # GAT Implementation
#
# This notebook demonstrates the GAT architecture implementation.

# %%
import torch
import torch.nn as nn
from models.gat import GAT
from config.config import GATConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement GAT model demonstration
config = GATConfig()
model = GAT(config)
print(model)
