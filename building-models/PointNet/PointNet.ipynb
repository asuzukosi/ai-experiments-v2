# %% [markdown]
# # PointNet Implementation
#
# This notebook demonstrates the PointNet architecture implementation.

# %%
import torch
import torch.nn as nn
from models.pointnet import PointNet
from config.config import PointNetConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement PointNet model demonstration
config = PointNetConfig()
model = PointNet(config)
print(model)
