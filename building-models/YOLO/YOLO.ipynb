# %% [markdown]
# # YOLO Implementation
#
# This notebook demonstrates the YOLO architecture implementation.

# %%
import torch
import torch.nn as nn
from models.yolo import YOLO
from config.config import YOLOConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement YOLO model demonstration
config = YOLOConfig()
model = YOLO(config)
print(model)
