# %% [markdown]
# # BERT Implementation
#
# This notebook demonstrates the BERT architecture implementation.

# %%
import torch
import torch.nn as nn
from models.bert import BERT
from config.config import BERTConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement BERT model demonstration
config = BERTConfig()
model = BERT(config)
print(model)
