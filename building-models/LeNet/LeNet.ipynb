# %% [markdown]
# # LeNet Implementation
#
# This notebook demonstrates the LeNet architecture implementation.

# %%
import torch
import torch.nn as nn
from models.lenet import LeNet
from config.config import LeNetConfig

# %% [markdown]
# ## Model Architecture

# %%
# TODO: Implement LeNet model demonstration
config = LeNetConfig()
model = LeNet(config)
print(model)
